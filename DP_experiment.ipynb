# %% [markdown]
# # Download and Unzip Dataset

# %%
# !pip install tensorflow_privacy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow_privacy in /usr/local/lib/python3.10/dist-packages (0.8.9)
# Requirement already satisfied: absl-py==1.*,>=1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_privacy) (1.0.0)
# Requirement already satisfied: attrs~=21.4 in /usr/local/lib/python3.10/dist-packages (from tensorflow_privacy) (21.4.0)
# Requirement already satisfied: dm-tree==0.1.8 in /usr/local/lib/python3.10/dist-packages (from tensorflow_privacy) (0.1.8)
# Requirement already satisfied: dp-accounting==0.4.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow_privacy) (0.4.1)
# Requirement already satisfied: immutabledict~=2.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow_privacy) (2.2.4)
# Requirement already satisfied: matplotlib~=3.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow_privacy) (3.7.1)
# Requirement already satisfied: numpy~=1.21 in /usr/local/lib/python3.10/dist-packages (from tensorflow_privacy) (1.22.4)
# Requirement already satisfied: packaging~=22.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_privacy) (22.0)
# Requirement already satisfied: pandas~=1.4 in /usr/local/lib/python3.10/dist-packages (from tensorflow_privacy) (1.5.3)
# Requirement already satisfied: parameterized~=0.8 in /usr/local/lib/python3.10/dist-packages (from tensorflow_privacy) (0.9.0)
# Requirement already satisfied: scikit-learn==1.*,>=1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_privacy) (1.2.2)
# Requirement already satisfied: scipy~=1.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow_privacy) (1.7.3)
# Requirement already satisfied: statsmodels~=0.13 in /usr/local/lib/python3.10/dist-packages (from tensorflow_privacy) (0.13.5)
# Requirement already satisfied: tensorflow-datasets~=4.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow_privacy) (4.9.2)
# Requirement already satisfied: tensorflow-estimator~=2.4 in /usr/local/lib/python3.10/dist-packages (from tensorflow_privacy) (2.12.0)
# Requirement already satisfied: tensorflow-probability==0.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_privacy) (0.15.0)
# Requirement already satisfied: tensorflow~=2.4 in /usr/local/lib/python3.10/dist-packages (from tensorflow_privacy) (2.12.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from absl-py==1.*,>=1.0->tensorflow_privacy) (1.16.0)
# Requirement already satisfied: mpmath~=1.2.1 in /usr/local/lib/python3.10/dist-packages (from dp-accounting==0.4.1->tensorflow_privacy) (1.2.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.*,>=1.0->tensorflow_privacy) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.*,>=1.0->tensorflow_privacy) (3.1.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability==0.15.0->tensorflow_privacy) (4.4.2)
# Requirement already satisfied: cloudpickle>=1.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability==0.15.0->tensorflow_privacy) (2.2.1)
# Requirement already satisfied: gast>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability==0.15.0->tensorflow_privacy) (0.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.3->tensorflow_privacy) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.3->tensorflow_privacy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.3->tensorflow_privacy) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.3->tensorflow_privacy) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.3->tensorflow_privacy) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.3->tensorflow_privacy) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.3->tensorflow_privacy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas~=1.4->tensorflow_privacy) (2022.7.1)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels~=0.13->tensorflow_privacy) (0.5.3)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow_privacy) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow_privacy) (23.3.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow_privacy) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow_privacy) (1.54.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow_privacy) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow_privacy) (0.4.8)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow_privacy) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow_privacy) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow_privacy) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow_privacy) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow_privacy) (67.7.2)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow_privacy) (2.12.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow_privacy) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow_privacy) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow_privacy) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow_privacy) (0.32.0)
# Requirement already satisfied: array-record in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets~=4.5->tensorflow_privacy) (0.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets~=4.5->tensorflow_privacy) (8.1.3)
# Requirement already satisfied: etils[enp,epath]>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets~=4.5->tensorflow_privacy) (1.2.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets~=4.5->tensorflow_privacy) (2.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets~=4.5->tensorflow_privacy) (5.9.5)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets~=4.5->tensorflow_privacy) (2.27.1)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets~=4.5->tensorflow_privacy) (1.13.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets~=4.5->tensorflow_privacy) (0.10.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets~=4.5->tensorflow_privacy) (4.65.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow~=2.4->tensorflow_privacy) (0.40.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets~=4.5->tensorflow_privacy) (5.12.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets~=4.5->tensorflow_privacy) (3.15.0)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow~=2.4->tensorflow_privacy) (0.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->tensorflow-datasets~=4.5->tensorflow_privacy) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->tensorflow-datasets~=4.5->tensorflow_privacy) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->tensorflow-datasets~=4.5->tensorflow_privacy) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->tensorflow-datasets~=4.5->tensorflow_privacy) (3.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.4->tensorflow_privacy) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.4->tensorflow_privacy) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.4->tensorflow_privacy) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.4->tensorflow_privacy) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.4->tensorflow_privacy) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.4->tensorflow_privacy) (2.3.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-metadata->tensorflow-datasets~=4.5->tensorflow_privacy) (1.59.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow~=2.4->tensorflow_privacy) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow~=2.4->tensorflow_privacy) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow~=2.4->tensorflow_privacy) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow~=2.4->tensorflow_privacy) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow~=2.4->tensorflow_privacy) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow~=2.4->tensorflow_privacy) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow~=2.4->tensorflow_privacy) (3.2.2)

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1n-wc8ebopNacuTNdtGrkn7A7r7UOjBj7' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1n-wc8ebopNacuTNdtGrkn7A7r7UOjBj7" -O Dataset.zip && rm -rf /tmp/cookies.txt
# Out:
# --2023-05-22 02:59:28--  https://docs.google.com/uc?export=download&confirm=t&id=1n-wc8ebopNacuTNdtGrkn7A7r7UOjBj7
# Resolving docs.google.com (docs.google.com)... 74.125.200.113, 74.125.200.100, 74.125.200.102, ...
# Connecting to docs.google.com (docs.google.com)|74.125.200.113|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0s-20-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/li1l8eqjinmepqv5taj4bkvuhb7ibelb/1684724325000/14323669513596321114/*/1n-wc8ebopNacuTNdtGrkn7A7r7UOjBj7?e=download&uuid=f1a5d03b-28a1-456b-bba7-e2f8a0778c18 [following]
# Warning: wildcards not supported in HTTP.
# --2023-05-22 02:59:28--  https://doc-0s-20-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/li1l8eqjinmepqv5taj4bkvuhb7ibelb/1684724325000/14323669513596321114/*/1n-wc8ebopNacuTNdtGrkn7A7r7UOjBj7?e=download&uuid=f1a5d03b-28a1-456b-bba7-e2f8a0778c18
# Resolving doc-0s-20-docs.googleusercontent.com (doc-0s-20-docs.googleusercontent.com)... 142.251.12.132, 2404:6800:4003:c11::84
# Connecting to doc-0s-20-docs.googleusercontent.com (doc-0s-20-docs.googleusercontent.com)|142.251.12.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 800754894 (764M) [application/zip]
# Saving to: ‘Dataset.zip’
#
# Dataset.zip         100%[===================>] 763.66M   253MB/s    in 3.0s
#
# 2023-05-22 02:59:32 (253 MB/s) - ‘Dataset.zip’ saved [800754894/800754894]

# %%
# !unzip Dataset.zip
# Out:
# Archive:  Dataset.zip
# replace Dataset/walking/person01_walking_d1_uncomp.avi? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: Dataset/walking/person01_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person01_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person01_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person01_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person02_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person02_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person02_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person02_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person03_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person03_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person03_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person03_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person04_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person04_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person04_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person04_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person05_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person05_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person05_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person05_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person06_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person06_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person06_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person06_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person07_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person07_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person07_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person07_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person08_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person08_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person08_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person08_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person09_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person09_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person09_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person09_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person10_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person10_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person10_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person10_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person11_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person11_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person11_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person11_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person12_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person12_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person12_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person12_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person13_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person13_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person13_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person13_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person14_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person14_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person14_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person14_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person15_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person15_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person15_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person15_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person16_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person16_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person16_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person16_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person17_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person17_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person17_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person17_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person18_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person18_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person18_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person18_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person19_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person19_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person19_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person19_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person20_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person20_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person20_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person20_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person21_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person21_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person21_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person21_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person22_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person22_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person22_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person22_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person23_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person23_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person23_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person23_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person24_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person24_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person24_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person24_walking_d4_uncomp.avi
#   inflating: Dataset/walking/person25_walking_d1_uncomp.avi
#   inflating: Dataset/walking/person25_walking_d2_uncomp.avi
#   inflating: Dataset/walking/person25_walking_d3_uncomp.avi
#   inflating: Dataset/walking/person25_walking_d4_uncomp.avi
#   inflating: Dataset/fights/newfi1.avi
#   inflating: Dataset/fights/newfi10.avi
#   inflating: Dataset/fights/newfi100.avi
#   inflating: Dataset/fights/newfi11.avi
#   inflating: Dataset/fights/newfi12.avi
#   inflating: Dataset/fights/newfi13.avi
#   inflating: Dataset/fights/newfi14.avi
#   inflating: Dataset/fights/newfi15.avi
#   inflating: Dataset/fights/newfi16.avi
#   inflating: Dataset/fights/newfi17.avi
#   inflating: Dataset/fights/newfi18.avi
#   inflating: Dataset/fights/newfi19.avi
#   inflating: Dataset/fights/newfi2.avi
#   inflating: Dataset/fights/newfi20.avi
#   inflating: Dataset/fights/newfi21.avi
#   inflating: Dataset/fights/newfi22.avi
#   inflating: Dataset/fights/newfi23.avi
#   inflating: Dataset/fights/newfi24.avi
#   inflating: Dataset/fights/newfi25.avi
#   inflating: Dataset/fights/newfi26.avi
#   inflating: Dataset/fights/newfi27.avi
#   inflating: Dataset/fights/newfi28.avi
#   inflating: Dataset/fights/newfi29.avi
#   inflating: Dataset/fights/newfi3.avi
#   inflating: Dataset/fights/newfi30.avi
#   inflating: Dataset/fights/newfi31.avi
#   inflating: Dataset/fights/newfi32.avi
#   inflating: Dataset/fights/newfi33.avi
#   inflating: Dataset/fights/newfi34.avi
#   inflating: Dataset/fights/newfi35.avi
#   inflating: Dataset/fights/newfi36.avi
#   inflating: Dataset/fights/newfi37.avi
#   inflating: Dataset/fights/newfi38.avi
#   inflating: Dataset/fights/newfi39.avi
#   inflating: Dataset/fights/newfi4.avi
#   inflating: Dataset/fights/newfi40.avi
#   inflating: Dataset/fights/newfi41.avi
#   inflating: Dataset/fights/newfi42.avi
#   inflating: Dataset/fights/newfi43.avi
#   inflating: Dataset/fights/newfi44.avi
#   inflating: Dataset/fights/newfi45.avi
#   inflating: Dataset/fights/newfi46.avi
#   inflating: Dataset/fights/newfi47.avi
#   inflating: Dataset/fights/newfi48.avi
#   inflating: Dataset/fights/newfi49.avi
#   inflating: Dataset/fights/newfi5.avi
#   inflating: Dataset/fights/newfi50.avi
#   inflating: Dataset/fights/newfi51.avi
#   inflating: Dataset/fights/newfi52.avi
#   inflating: Dataset/fights/newfi53.avi
#   inflating: Dataset/fights/newfi54.avi
#   inflating: Dataset/fights/newfi55.avi
#   inflating: Dataset/fights/newfi56.avi
#   inflating: Dataset/fights/newfi57.avi
#   inflating: Dataset/fights/newfi58.avi
#   inflating: Dataset/fights/newfi59.avi
#   inflating: Dataset/fights/newfi6.avi
#   inflating: Dataset/fights/newfi60.avi
#   inflating: Dataset/fights/newfi61.avi
#   inflating: Dataset/fights/newfi62.avi
#   inflating: Dataset/fights/newfi63.avi
#   inflating: Dataset/fights/newfi64.avi
#   inflating: Dataset/fights/newfi65.avi
#   inflating: Dataset/fights/newfi66.avi
#   inflating: Dataset/fights/newfi67.avi
#   inflating: Dataset/fights/newfi68.avi
#   inflating: Dataset/fights/newfi69.avi
#   inflating: Dataset/fights/newfi7.avi
#   inflating: Dataset/fights/newfi70.avi
#   inflating: Dataset/fights/newfi71.avi
#   inflating: Dataset/running/person21_running_d3_uncomp.avi
#   inflating: Dataset/running/person21_running_d4_uncomp.avi
#   inflating: Dataset/running/person22_running_d1_uncomp.avi
#   inflating: Dataset/running/person22_running_d2_uncomp.avi
#   inflating: Dataset/running/person22_running_d3_uncomp.avi
#   inflating: Dataset/running/person22_running_d4_uncomp.avi
#   inflating: Dataset/running/person23_running_d1_uncomp.avi
#   inflating: Dataset/running/person23_running_d2_uncomp.avi
#   inflating: Dataset/running/person23_running_d3_uncomp.avi
#   inflating: Dataset/running/person23_running_d4_uncomp.avi
#   inflating: Dataset/running/person24_running_d1_uncomp.avi
#   inflating: Dataset/running/person24_running_d2_uncomp.avi
#   inflating: Dataset/running/person24_running_d3_uncomp.avi
#   inflating: Dataset/running/person24_running_d4_uncomp.avi
#   inflating: Dataset/running/person25_running_d1_uncomp.avi
#   inflating: Dataset/running/person25_running_d2_uncomp.avi
#   inflating: Dataset/running/person25_running_d3_uncomp.avi
#   inflating: Dataset/running/person25_running_d4_uncomp.avi

# %% [markdown]
# # Import Required Libraries

# %%
# !pip install pafy youtube-dl moviepy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pafy in /usr/local/lib/python3.10/dist-packages (0.5.5)
# Requirement already satisfied: youtube-dl in /usr/local/lib/python3.10/dist-packages (2021.12.17)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.10/dist-packages (1.0.3)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.10/dist-packages (from moviepy) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.10/dist-packages (from moviepy) (4.65.0)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from moviepy) (2.27.1)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.10/dist-packages (from moviepy) (0.1.10)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from moviepy) (1.22.4)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.10/dist-packages (from moviepy) (2.25.1)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from moviepy) (0.4.8)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio<3.0,>=2.5->moviepy) (8.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.4)

# %%
import os
import cv2
import pafy
import math
import random
import numpy as np
import datetime as dt
import tensorflow as tf
from collections import deque
import matplotlib.pyplot as plt

from moviepy.editor import *
# %matplotlib inline

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model

# %% [markdown]
# # Select Randomness

# %%
seed_constant = 5
np.random.seed(seed_constant)
random.seed(seed_constant)
tf.random.set_seed(seed_constant)

# %% [markdown]
# # View the dataset

# %%
# Create a Matplotlib figure and specify the size of the figure.
plt.figure(figsize = (20, 20))

# Get the names of all classes/categories in UCF50.
all_classes_names = os.listdir('Dataset')

# Generate a list of 20 random values. The values will be between 0-50,
# where 50 is the total number of class in the dataset.
# random_range = random.sample(range(len(all_classes_names)), len(all_classes_names))

# Iterating through all the generated random values.
for counter, random_index in enumerate(range(len(all_classes_names)), 1):

    # Retrieve a Class Name using the Random Index.
    selected_class_Name = all_classes_names[random_index]

    # Retrieve the list of all the video files present in the randomly selected Class Directory.
    video_files_names_list = os.listdir(f'Dataset/{selected_class_Name}')

    # Randomly select a video file from the list retrieved from the randomly selected Class Directory.
    selected_video_file_name = random.choice(video_files_names_list)

    # Initialize a VideoCapture object to read from the video File.
    video_reader = cv2.VideoCapture(f'Dataset/{selected_class_Name}/{selected_video_file_name}')
    video_reader.set(1, 25)

    # Read the first frame of the video file.
    _, bgr_frame = video_reader.read()

    bgr_frame = cv2.resize(bgr_frame ,(224,224))
    # Release the VideoCapture object.
    video_reader.release()

    # Convert the frame from BGR into RGB format.
    rgb_frame = cv2.cvtColor(bgr_frame, cv2.COLOR_BGR2RGB)

    # Write the class name on the video frame.
    cv2.putText(rgb_frame, selected_class_Name, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 200, 255), 2)

    # Display the frame.
    plt.subplot(5, 4, counter);plt.imshow(rgb_frame);plt.axis('off')

# %% [markdown]
# # Set Dataset Variables

# %%
# Specify the height and width to which each video frame will be resized in our dataset.
IMAGE_HEIGHT , IMAGE_WIDTH = 64, 64

# Specify the number of frames of a video that will be fed to the model as one sequence.
SEQUENCE_LENGTH = 30

# Specify the directory containing the UCF50 dataset.
DATASET_DIR = "Dataset"

# Specify the list containing the names of the classes used for training. Feel free to choose any set of classes.
CLASSES_LIST = ["walking", "fights", "running"]

# %% [markdown]
# # Data pre-processing

# %%
def frames_extraction(video_path):
    '''
    This function will extract the required frames from a video after resizing and normalizing them.
    Args:
        video_path: The path of the video in the disk, whose frames are to be extracted.
    Returns:
        frames_list: A list containing the resized and normalized frames of the video.
    '''

    # Declare a list to store video frames.
    frames_list = []

    # Read the Video File using the VideoCapture object.
    video_reader = cv2.VideoCapture(video_path)

    # Get the total number of frames in the video.
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))

    # Calculate the the interval after which frames will be added to the list.
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH), 1)

    # Iterate through the Video Frames.
    for frame_counter in range(SEQUENCE_LENGTH):

        # Set the current frame position of the video.
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)

        # Reading the frame from the video.
        success, frame = video_reader.read()

        # Check if Video frame is not successfully read then break the loop
        if not success:
            break

        # Resize the Frame to fixed height and width.
        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))

        # Normalize the resized frame by dividing it with 255 so that each pixel value then lies between 0 and 1
        normalized_frame = resized_frame / 255

        # Append the normalized frame into the frames list
        frames_list.append(normalized_frame)

    # Release the VideoCapture object.
    video_reader.release()

    # Return the frames list.
    return frames_list

# %%
def create_dataset():
    '''
    This function will extract the data of the selected classes and create the required dataset.
    Returns:
        features:          A list containing the extracted frames of the videos.
        labels:            A list containing the indexes of the classes associated with the videos.
        video_files_paths: A list containing the paths of the videos in the disk.
    '''

    # Declared Empty Lists to store the features, labels and video file path values.
    features = []
    labels = []
    video_files_paths = []

    # Iterating through all the classes mentioned in the classes list
    for class_index, class_name in enumerate(CLASSES_LIST):

        # Display the name of the class whose data is being extracted.
        print(f'Extracting Data of Class: {class_name}')

        # Get the list of video files present in the specific class name directory.
        files_list = os.listdir(os.path.join(DATASET_DIR, class_name))

        # Iterate through all the files present in the files list.
        for file_name in files_list:

            # Get the complete video path.
            video_file_path = os.path.join(DATASET_DIR, class_name, file_name)

            # Extract the frames of the video file.
            frames = frames_extraction(video_file_path)

            # Check if the extracted frames are equal to the SEQUENCE_LENGTH specified above.
            # So ignore the vides having frames less than the SEQUENCE_LENGTH.
            if len(frames) == SEQUENCE_LENGTH:

                # Append the data to their repective lists.
                features.append(frames)
                labels.append(class_index)
                video_files_paths.append(video_file_path)

    # Converting the list to numpy arrays
    features = np.asarray(features)
    labels = np.array(labels)

    # Return the frames, class index, and video file path.
    return features, labels, video_files_paths

# %%
# Create the dataset.
features, labels, video_files_paths = create_dataset()
# Out:
# Extracting Data of Class: walking
# Extracting Data of Class: fights
# Extracting Data of Class: running

# %%
# Using Keras's to_categorical method to convert labels into one-hot-encoded vectors
one_hot_encoded_labels = to_categorical(labels)

# %%
# Split the Data into Train ( 75% ) and Test Set ( 25% ).
features_train, features_test, labels_train, labels_test = train_test_split(features, one_hot_encoded_labels, test_size = 0.25, shuffle = True, random_state = seed_constant)
features = None
labels = None

# %% [markdown]
# # Model Creation LRCN (Long-term Recurrent Convolutional Network)

# %%
def create_LRCN_model():
    '''
    This function will construct the required LRCN model.
    Returns:
        model: It is the required constructed LRCN model.
    '''

    # We will use a Sequential model for model construction.
    model = Sequential()

    # Define the Model Architecture.
    ########################################################################################################################

    model.add(TimeDistributed(Conv2D(32, (3, 3), padding='same',activation = 'relu'), input_shape = (SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)))
    model.add(TimeDistributed(MaxPooling2D((4, 4))))

    model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same',activation = 'relu')))
    model.add(TimeDistributed(MaxPooling2D((4, 4))))

    model.add(TimeDistributed(Conv2D(128, (3, 3), padding='same',activation = 'relu')))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))

    model.add(TimeDistributed(Conv2D(256, (2, 2), padding='same',activation = 'relu')))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))

    model.add(TimeDistributed(Flatten()))

    model.add(LSTM(32))

    model.add(Dense(len(CLASSES_LIST), activation = 'softmax'))

    ########################################################################################################################

    # Display the models summary.
    model.summary()

    # Return the constructed LRCN model.
    return model

# %%
model = create_LRCN_model()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_36 (TimeDi  (None, 30, 64, 64, 32)   896
#  stributed)
#
#  time_distributed_37 (TimeDi  (None, 30, 16, 16, 32)   0
#  stributed)
#
#  time_distributed_38 (TimeDi  (None, 30, 16, 16, 64)   18496
#  stributed)
#
#  time_distributed_39 (TimeDi  (None, 30, 4, 4, 64)     0
#  stributed)
#
#  time_distributed_40 (TimeDi  (None, 30, 4, 4, 128)    73856
#  stributed)
#
#  time_distributed_41 (TimeDi  (None, 30, 2, 2, 128)    0
#  stributed)
#
#  time_distributed_42 (TimeDi  (None, 30, 2, 2, 256)    131328
#  stributed)
#
#  time_distributed_43 (TimeDi  (None, 30, 1, 1, 256)    0
#  stributed)
#
#  time_distributed_44 (TimeDi  (None, 30, 256)          0
#  stributed)
#
#  lstm_4 (LSTM)               (None, 32)                36992
#
#  dense_4 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 261,667
# Trainable params: 261,667
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Model Training

# %%
from tensorflow_privacy.privacy.optimizers.dp_optimizer_keras import DPKerasAdamOptimizer
from tensorflow_privacy.privacy.analysis import compute_dp_sgd_privacy_lib

# Define parameters for Differential Privacy
l2_norm_clip = 1  # Increase the l2_norm_clip slightly to allow individual points to contribute more
noise_multiplier = 1.6  # Decrease the noise_multiplier slightly to add less noise

dp_optimizer = DPKerasAdamOptimizer(
    l2_norm_clip=l2_norm_clip,
    noise_multiplier=noise_multiplier,
    num_microbatches=1,
)

# Create an Instance of Early Stopping Callback.
early_stopping_callback = EarlyStopping(monitor = 'accuracy', patience = 10, mode = 'max', restore_best_weights = True)

# Compile the model and specify loss function, optimizer and metrics to the model.
model.compile(loss = 'categorical_crossentropy', optimizer = dp_optimizer, metrics = ["accuracy"])

# Start training the model.
epochs = 70
batch_size = 4
model_training_history = model.fit(x = features_train, y = labels_train, epochs = epochs, batch_size = batch_size, shuffle = True, validation_split = 0.25, callbacks = [early_stopping_callback])

# Compute the privacy budget expended
delta = 1e-5 # You might need to adjust this value depending on your dataset size
N = len(features_train)  # number of training samples
steps = epochs * N // batch_size
epsilon = compute_dp_sgd_privacy_lib.compute_dp_sgd_privacy_statement(number_of_examples=N, batch_size=batch_size, noise_multiplier=noise_multiplier, num_epochs=epochs, delta=delta)

print('Epsilon:', epsilon)
# Out:
# Epoch 1/70
# 42/42 [==============================] - 23s 282ms/step - loss: 1.1034 - accuracy: 0.1250 - val_loss: 1.1004 - val_accuracy: 0.1754
# Epoch 2/70
# 42/42 [==============================] - 13s 307ms/step - loss: 1.0979 - accuracy: 0.2619 - val_loss: 1.0946 - val_accuracy: 0.3509
# Epoch 3/70
# 42/42 [==============================] - 13s 305ms/step - loss: 1.0979 - accuracy: 0.2976 - val_loss: 1.0981 - val_accuracy: 0.2982
# Epoch 4/70
# 42/42 [==============================] - 11s 253ms/step - loss: 1.1003 - accuracy: 0.3155 - val_loss: 1.1067 - val_accuracy: 0.2807
# Epoch 5/70
# 42/42 [==============================] - 12s 277ms/step - loss: 1.1020 - accuracy: 0.3274 - val_loss: 1.1105 - val_accuracy: 0.2982
# Epoch 6/70
# 42/42 [==============================] - 13s 305ms/step - loss: 1.1038 - accuracy: 0.3631 - val_loss: 1.1132 - val_accuracy: 0.3158
# Epoch 7/70
# 42/42 [==============================] - 12s 298ms/step - loss: 1.1070 - accuracy: 0.3452 - val_loss: 1.1142 - val_accuracy: 0.3158
# Epoch 8/70
# 42/42 [==============================] - 10s 228ms/step - loss: 1.1071 - accuracy: 0.3452 - val_loss: 1.1187 - val_accuracy: 0.3158
# Epoch 9/70
# 42/42 [==============================] - 13s 308ms/step - loss: 1.1051 - accuracy: 0.3452 - val_loss: 1.1125 - val_accuracy: 0.3158
# Epoch 10/70
# 42/42 [==============================] - 13s 303ms/step - loss: 1.1051 - accuracy: 0.3452 - val_loss: 1.1166 - val_accuracy: 0.3158
# Epoch 11/70
# 42/42 [==============================] - 11s 266ms/step - loss: 1.1035 - accuracy: 0.3452 - val_loss: 1.1136 - val_accuracy: 0.3158
# Epoch 12/70
# 42/42 [==============================] - 11s 259ms/step - loss: 1.1041 - accuracy: 0.3452 - val_loss: 1.1187 - val_accuracy: 0.3158
# Epoch 13/70
# 42/42 [==============================] - 13s 302ms/step - loss: 1.1026 - accuracy: 0.3452 - val_loss: 1.1200 - val_accuracy: 0.3158
# Epoch 14/70
# 42/42 [==============================] - 13s 305ms/step - loss: 1.1012 - accuracy: 0.3452 - val_loss: 1.1231 - val_accuracy: 0.3158
# Epoch 15/70
# 42/42 [==============================] - 10s 229ms/step - loss: 1.1029 - accuracy: 0.3452 - val_loss: 1.1308 - val_accuracy: 0.3158
# Epoch 16/70
# 42/42 [==============================] - 13s 302ms/step - loss: 1.1065 - accuracy: 0.3452 - val_loss: 1.1330 - val_accuracy: 0.3158
# Epsilon: DP-SGD performed over 225 examples with 4 examples per iteration, noise
# multiplier 1.6 for 70 epochs with microbatching, and no bound on number of
# examples per user.
#
# This privacy guarantee protects the release of all model checkpoints in addition
# to the final model.
#
# Example-level DP with add-or-remove-one adjacency at delta = 1e-05 computed with
# RDP accounting:
#     Epsilon with each example occurring once per epoch:       103.148
#     Epsilon assuming Poisson sampling (*):                     12.666
#
# No user-level privacy guarantee is possible without a bound on the number of
# examples per user.
#
# (*) Poisson sampling is not usually done in training pipelines, but assuming
# that the data was randomly shuffled, it is believed the actual epsilon should be
# closer to this value than the conservative assumption of an arbitrary data
# order.

# %% [markdown]
# # Save Model

# %%
# Save your Model.
model.save("Suspicious_Human_Activity_Detection_LRCN_Model.h5")

# %% [markdown]
# # Accuracy on Test Dataset

# %%
# Calculate Accuracy On Test Dataset
acc = 0
for i in range(len(features_test)):
  predicted_label = np.argmax(model.predict(np.expand_dims(features_test[i],axis =0))[0])
  actual_label = np.argmax(labels_test[i])
  if predicted_label == actual_label:
      acc += 1
acc = (acc * 100)/len(labels_test)
print("Accuracy =",acc)
# Out:
# 1/1 [==============================] - 0s 454ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# Accuracy = 33.333333333333336

# %%
def predict_single_action(video_file_path, SEQUENCE_LENGTH):
    '''
    This function will perform single action recognition prediction on a video using the LRCN model.
    Args:
    video_file_path:  The path of the video stored in the disk on which the action recognition is to be performed.
    SEQUENCE_LENGTH:  The fixed number of frames of a video that can be passed to the model as one sequence.
    '''

    # Initialize the VideoCapture object to read from the video file.
    video_reader = cv2.VideoCapture(video_file_path)

    # Get the width and height of the video.
    original_video_width = int(video_reader.get(cv2.CAP_PROP_FRAME_WIDTH))
    original_video_height = int(video_reader.get(cv2.CAP_PROP_FRAME_HEIGHT))

    # Declare a list to store video frames we will extract.
    frames_list = []

    # Initialize a variable to store the predicted action being performed in the video.
    predicted_class_name = ''

    # Get the number of frames in the video.
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))

    # Calculate the interval after which frames will be added to the list.
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH),1)

    # Iterating the number of times equal to the fixed length of sequence.
    for frame_counter in range(SEQUENCE_LENGTH):

        # Set the current frame position of the video.
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)

        # Read a frame.
        success, frame = video_reader.read()

        # Check if frame is not read properly then break the loop.
        if not success:
            break

        # Resize the Frame to fixed Dimensions.
        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))

        # Normalize the resized frame by dividing it with 255 so that each pixel value then lies between 0 and 1.
        normalized_frame = resized_frame / 255

        # Appending the pre-processed frame into the frames list
        frames_list.append(normalized_frame)

    # Passing the  pre-processed frames to the model and get the predicted probabilities.
    predicted_labels_probabilities = model.predict(np.expand_dims(frames_list, axis = 0))[0]

    # Get the index of class with highest probability.
    predicted_label = np.argmax(predicted_labels_probabilities)

    # Get the class name using the retrieved index.
    predicted_class_name = CLASSES_LIST[predicted_label]

    # Display the predicted action along with the prediction confidence.
    print(f'Action Predicted: {predicted_class_name}\nConfidence: {predicted_labels_probabilities[predicted_label]}')

    # Release the VideoCapture object.
    video_reader.release()

# %%
predict_single_action("Predict/fight.avi",SEQUENCE_LENGTH)
# Out:
# 1/1 [==============================] - 0s 24ms/step
# Action Predicted: walking
# Confidence: 0.3519902229309082

# %%
predict_single_action("Predict/running.avi",SEQUENCE_LENGTH)
# Out:
# 1/1 [==============================] - 0s 29ms/step
# Action Predicted: walking
# Confidence: 0.3464847207069397

# %%
predict_single_action("Predict/walking.avi",SEQUENCE_LENGTH)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# Action Predicted: walking
# Confidence: 0.35705193877220154
